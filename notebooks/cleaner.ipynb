# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ats_df = pd.read_csv('../datasets/ats.csv')
hr_df = pd.read_csv('../datasets/hr_bob_06_12.csv')

# %%
ats_df.columns
# Out:
# Index(['id', 'customfields_candidateexp',
#        'applications_jobdetails_customfields_joblevel',
#        'applications_jobs_name', 'customfields_gender',
#        'customfields_candidateage', 'customfields_dateofbirth',
#        'customfields_language', 'applications_location_address',
#        'applications_jobdetails_hiringteam_hiringmanagers_name',
#        'applications_jobdetails_departments_name', 'customfields_hiredate',
#        'customfields_startdate', 'applications_offerdetails_resolvedat',
#        'applications_offerdetails_createdat', 'applications_appliedat',
#        'applications_jobdetails_openings_openedat',
#        'applications_jobdetails_openings_closedat', 'customfields_degree',
#        'customfields_discipline', 'applications_source_publicname',
#        'applications_rejectedat', 'applications_status',
#        'applications_jobdetails_status', 'applications_offerdetails_status',
#        'recruiter_name', 'applications_rejectionreason_name',
# ...

# %%
correlated_df = hr_df.merge(ats_df, on='id', how='inner')

# %%
correlated_df.shape
# Out:
# (127, 96)
